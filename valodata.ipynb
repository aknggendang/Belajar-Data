# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
agentds = pd.read_csv("/home/alfascale/Documents/Python/Data Science Series/valorant_agent.csv")
agentds
# Out:
#           name         role                   alias real_name  \
# 0    Brimstone   Controller                 Big Man       NaN
# 1        Viper   Controller                     NaN    Sabine
# 2         Omen   Controller  "Ja-" (partial reveal)       NaN
# 3      Killjoy     Sentinel                     NaN       NaN
# 4       Cypher     Sentinel                     NaN     Aamir
# 5         Sova    Initiator                     NaN       NaN
# 6         Sage     Sentinel                     NaN       NaN
# 7      Phoenix      Duelist                     NaN       NaN
# 8         Jett      Duelist                     NaN  Joon-Hee
# 9        Reyna      Duelist                     NaN       NaN
# 10        Raze      Duelist                     NaN       NaN
# 11      Breach    Initiator                 Breachy       NaN
# 12        Skye    Initiator                     NaN       NaN
# 13        Yoru      Duelist                     NaN       NaN
# ...

# %%
agentds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16 non-null     object
#  1   role              16 non-null     object
#  2   alias             3 non-null      object
#  3   real_name         3 non-null      object
#  4   origin            16 non-null     object
#  5   race              16 non-null     object
#  6   gender            16 non-null     object
#  7   affiliation       16 non-null     object
#  8   appearances       16 non-null     object
#  9   voice_actor       16 non-null     object
#  10  passive1          3 non-null      object
#  11  passive2          1 non-null      object
#  12  basic1            16 non-null     object
#  13  basic2            15 non-null     object
#  14  basic3            1 non-null      object
#  15  signature1        16 non-null     object
# ...

# %%
agentds.loc[7]
# Out:
# name                          Phoenix
# role                          Duelist
# alias                             NaN
# real_name                         NaN
# origin                 United Kingdom
# race                          Radiant
# gender                           Male
# affiliation         VALORANT Protocol
# appearances                  VALORANT
# voice_actor              Afolabi Alli
# passive1                          NaN
# passive2                          NaN
# basic1                          Blaze
# basic2                      Curveball
# basic3                            NaN
# signature1                  Hot Hands
# signature2                        NaN
# ultimate                  Run It Back
# basic1_creds                    200.0
# basic2_creds                    250.0
# basic3_creds                      NaN
# signature1_creds                    0
# signature2_creds                  NaN
# ultimate_points                     6
# Name: 7, dtype: object

# %%
agentds["name"]
agentds["real_name"]
# Out:
# 0          NaN
# 1       Sabine
# 2          NaN
# 3          NaN
# 4        Aamir
# 5          NaN
# 6          NaN
# 7          NaN
# 8     Joon-Hee
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# Name: real_name, dtype: object
